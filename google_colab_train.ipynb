# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! nvidia-smi
# Out:
# Sat Jan 23 21:22:46 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
WORKDIR = '/content/drive/My Drive/VU/applied_text_mining/Assignment3/bert-entity-extraction'

# %%
! pip install transformers
# Out:
# ...
#      |████████████████████████████████| 1.8MB 7.8MB/s
# ...
#      |████████████████████████████████| 890kB 34.7MB/s
# ...
#      |████████████████████████████████| 2.9MB 52.2MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=558fbc2ed9ef90b3bbf47ffeafe531c787b4c3c9823cd363d7167589dfe1d0c3
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
! cd "$WORKDIR"/src && python train.py
# Out:
#   3% 1/29 [00:03<01:38,  3.53s/it]
# Traceback (most recent call last):
#   File "train.py", line 92, in <module>
#     train_data_loader, model, optimizer, device, scheduler
#   File "/content/drive/My Drive/VU/applied_text_mining/Assignment3/bert-entity-extraction/src/engine.py", line 12, in train_fn
#     _, loss = model(**data)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/drive/My Drive/VU/applied_text_mining/Assignment3/bert-entity-extraction/src/model.py", line 27, in forward
#     otp = self.bert(ids, attention_mask=mask, token_type_ids=token_type_ids)
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/transformers/models/bert/modeling_bert.py", line 968, in forward
#     return_dict=return_dict,
# ...

# %%
! cd "$WORKDIR"/src && python predict.py
# Out:
# Traceback (most recent call last):
#   File "predict.py", line 3, in <module>
#     import joblib
#   File "/usr/local/lib/python3.6/dist-packages/joblib/__init__.py", line 113, in <module>
#     from .memory import Memory, MemorizedResult, register_store_backend
#   File "/usr/local/lib/python3.6/dist-packages/joblib/memory.py", line 25, in <module>
#     from tokenize import open as open_py_source
# ImportError: cannot import name 'open'
